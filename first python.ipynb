# %% [markdown]
# # 标题
#
# - 1
# - 2
# - 3

# %%
num = 5*10*21

# %%
print(num)

# %%
False + 1

# %%
align = "abcde"

# %%
align.rjust(30)

# %%
align.ljust(30)

# %%
align.center(30)

# %%
rlign = align.rjust(30)
rlign.strip()

# %%
align.center(0)

# %%
clign = "    my name is donghongzhi    "
clign.strip( )

# %%
clign = "    my name is donghongzhi    "
clign.strip()

# %%
clign.upper()

# %%
clign.lower()

# %%
a =(2!=1)
a

# %%
a =2!=1
a

# %%
b = "asdfasdg454545"
b.isalnum()

# %%
a = "sdfa"
b = "asdga"
print(f'我是{a},他是{b}')

# %%
len("dafsdg")

# %%
100**2

# %%
pow(100.0,3)

# %%
a = 100
type(a)
print("a 是 {}".format(a))
b = 2
print("a+b = {}".format(a+b))

# %%
import os
os.system("pause")

# %%
pi_estimate = 0
flag = 0
for i in range(1,100000):
    if i % 2 != 0:
        if flag == 0:
            pi_estimate = pi_estimate + 1/i
            flag = 1
        else:
            pi_estimate = pi_estimate - 1/i
            flag = 0
print(pi_estimate*4)

# %%
weekdays = ["Monday","Friday","Sunday","Satuaday","Thusday","Wednesday"]
weekdays

# %%
weekdays.remove("Friday")
weekdays

# %%
"Friday" in weekdays

# %%
weekdays.pop(1)
weekdays

# %%
list1 = ['a','b','c']
list2 = ['d','e','f']
current_list = [list1,list2]
current_list

# %%
current_list[1][1]

# %%
print(current_list)

# %%
list1.sort(reverse=True)
list1

# %%
t_list = ["sf","sdf",1]
a,b,c = t_list

# %%
t_list[2] = 20

# %%
c

# %%
pizza = {1:"a",2:"b",3:"c"}
len(pizza)

# %%
pizza.keys()

# %%
tuple1 = (1,2)
tuple2 = (tuple1[0],tuple1[1],3)
tuple2

# %%
set1 = {1,2,3}
set2 = {1,3,4,5}
print(set1&set2)
print(set1|set2)
print(set1-set2)
print(set1^set2)

# %%
s1 = {1:2,3:4}
s2 = {5:6,7:8}
s = list(zip(s1,s2))
s

# %%
def say_hello(*args):
    print('hello {0}'.format(args))

# 通过位置传值
say_hello('jack', 'tom')

# %%
def func_b(**kwargs):
    print(kwargs)

# 通过关键字传值
func_b(a=1, b=2)

# %%
def func_c(*args, a, b):
    print(args,a,b)

# 只能通过关键字传值
func_c('test',a=1,b=2)

# %%
def func_d(a,*args,**kwargs):
    print(a,args,kwargs)
func_d(1,3,4,5,b=1,c=2)

# %%
import random
b = [1,2,3,4]
random.sample(b,3)

# %%
random.randint(5,6)

# %%
def div(op1,op2):
    try:
        return(op1/op2)
    except:
        print("除数不为零") 
    finally:
        print("hello world")
div(5,0)

# %%
s = "dsagadsg"
from random import choice
choice(s)

# %%
fout = open('text','wt')
ret = fout.write("dasgasdgasdg")
print(ret)
fout.close()

# %%
fout = open('text','r')
all_lines = fout.readline()
print(all_lines)
fout.close()

# %%
text = '''\
sdlfkasjdg
daskgladsjlkg
asdjglksaj

'''

# %%
fout = open('text','wt')
ret = fout.write(text)
print(ret)
fout.close()

# %%
a = 2
print(id(a))
a=3
print(id(a))

# %%
start_index=0
last_index=0
page_hero = '<ul class="herolist clearfix"><li><a href="herodetail/194.shtml" target="_blank"><img src="http://game.gtimg.cn/images/yxzj/img201606/heroimg/194/194.jpg" width="91px" alt="苏烈">苏烈</a></li><li><a href="herodetail/195.shtml" target="_blank"><img src="http://game.gtimg.cn/images/yxzj/img201606/heroimg/195/195.jpg" width="91px" alt="百里玄策">百里玄策</a></li><li><a href="herodetail/196.shtml" target="_blank"><img src="http://game.gtimg.cn/images/yxzj/img201606/heroimg/196/196.jpg" width="91px" alt="百里守约">百里守约</a></li><li><a href="herodetail/193.shtml" target="_blank"><img src="http://game.gtimg.cn/images/yxzj/img201606/heroimg/193/193.jpg" width="91px" alt="铠">铠</a></li></ul>'
def extract_hero_and_img(current_page):
    start_index = current_page.find("http:")
    last_index = current_page.find('"',start_index)
    start_name = current_page.find(">",last_index)
    last_name = current_page.find("<",start_name)
    if start_index != -1:
        print(current_page[start_index:last_index])
        print(current_page[start_name+1:last_name])
        return last_name
    else:
        return -1

# %%
while True:
    page_hero = page_hero[start_index:]
    start_index = extract_hero_and_img(page_hero)
    if start_index == -1:
        break

# %%
def a(b):
    b = b*(b-1)
    if

# %%
a = 'abcdefghijklmnapqistuvwxyz'
def algh(alpha):
    ret = alpha.find("a")
    print(ret)
    return ret+1

start_index = 0
while True:
    a = a[start_index:]
    start_index = algh(a)
    if start_index == 0:
        break
# Out:
# 0
# 13
# -1

# %%
import requests
header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}
r = requests.get('https://www.zhipin.com/job_detail/?query=%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90&city=101110100&industry=&position=',headers = header)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7 ]><html class="ie ie6"><![endif]-->\n<!--[if IE 7 ]><html class="ie ie7"><![endif]-->\n<!--[if IE 8 ]><html class="ie ie8"><![endif]-->\n<!--[if IE 9 ]><html class="ie9"><![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--><html class="standard"><!--<![endif]-->\n<head>\n    <meta charset="utf-8">\n    <title>【西安数据分析招聘】2019年西安数据分析最新人才招聘信息-BOSS直聘</title>\n    <meta name="keywords" content="西安数据分析招聘,西安数据分析人才网,西安数据分析招聘网"/>\n    <meta name="description" content="BOSS直聘为求职者提供2019年最新的西安数据分析招聘信息，百万Boss在线直聘，直接开聊，在线面试，找工作就上BOSS直聘网站或APP，直接与Boss开聊吧！"/>\n    <link href="https://static.zhipin.com/zhipin-geek/v15/web/geek/css/main.css" type="text/css" rel="stylesheet">\n    <link rel="canonical" href="https://www.zhipin.com/c101110100/?query=%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90">\n    <meta name="applicable-device" content="pc">\n    <meta name="mobile-agent" content="format=html5;url=https://m.zhipin.com/c101110100/?query=%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90">\n    <scrip
# ...

# %%
with open("boss_text.html","w",encoding = "utf-8") as fout:
    fout.write(r.text)

# %%
import jieba
a = jieba.cut("我在北京上大学")
print("\ ".join(a))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 2.509 seconds.
# Prefix dict has been built succesfully.
# 我\ 在\ 北京\ 上\ 大学
